# %% [markdown]
# # Import

# %%
from __future__ import division

from models import *
from utils.utils import *
from utils.datasets import *

import os
import sys
import time
import datetime
import argparse
import cv2

from PIL import Image

import torch
from torch.utils.data import DataLoader
from torchvision import datasets
from torch.autograd import Variable
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.ticker import NullLocator

# %% [markdown]
# # Arg Parse

# %%
# parser = argparse.ArgumentParser()
# parser.add_argument("--image_folder", type=str, default="data/samples", help="path to dataset")
# parser.add_argument("--model_def", type=str, default="config/yolov3.cfg", help="path to model definition file")
# parser.add_argument("--weights_path", type=str, default="weights/yolov3.weights", help="path to weights file")
# parser.add_argument("--class_path", type=str, default="data/coco.names", help="path to class label file")
# parser.add_argument("--conf_thres", type=float, default=0.8, help="object confidence threshold")
# parser.add_argument("--nms_thres", type=float, default=0.4, help="iou thresshold for non-maximum suppression")
# parser.add_argument("--batch_size", type=int, default=1, help="size of the batches")
# parser.add_argument("--n_cpu", type=int, default=0, help="number of cpu threads to use during batch generation")
# parser.add_argument("--img_size", type=int, default=416, help="size of each image dimension")
# parser.add_argument("--checkpoint_model", type=str, help="path to checkpoint model")
# opt = parser.parse_args()
# print(opt)

# %%
class opt:
    image_folder = "data/samples"
    model_def = "config/yolov3.cfg"
    weights_path = "weights/yolov3.weights"
    class_path = "data/coco.names"
    conf_thres = 0.8
    nms_thres = 0.4
    batch_size = 1
    n_cpu = 0
    img_size = 416
    checkpoint_model= str()

# %%
def plot_one_box(x, img, color=None, label=None, line_thickness=None):
    # Plots one bounding box on image img
    tl = line_thickness or round(0.002 * (img.shape[0] + img.shape[1]) / 2) + 1  # line/font thickness
    color = color or [random.randint(0, 255) for _ in range(3)]
    c1, c2 = (int(x[0]), int(x[1])), (int(x[2]), int(x[3]))
    cv2.rectangle(img, c1, c2, color, thickness=tl, lineType=cv2.LINE_AA)
    if label:
        tf = max(tl - 1, 1)  # font thickness
        t_size = cv2.getTextSize(label, 0, fontScale=tl / 3, thickness=tf)[0]
        c2 = c1[0] + t_size[0], c1[1] - t_size[1] - 3
        cv2.rectangle(img, c1, c2, color, -1, cv2.LINE_AA)  # filled
        cv2.putText(img, label, (c1[0], c1[1] - 2), 0, tl / 3, [225, 255, 255], thickness=tf, lineType=cv2.LINE_AA)

# %%
def figure_to_array(fig):
    """
    plt.figure를 RGBA로 변환(layer가 4개)
    shape: height, width, layer
    """
    fig.canvas.draw()
    return np.array(fig.canvas.renderer._renderer)

# %% [markdown]
# # Model Load

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

os.makedirs("output", exist_ok=True)

# Set up model
model = Darknet(opt.model_def, img_size=opt.img_size).to(device)

if opt.weights_path.endswith(".weights"):
    # Load darknet weights
    model.load_darknet_weights(opt.weights_path)
else:
    # Load checkpoint weights
    model.load_state_dict(torch.load(opt.weights_path))

model.eval()  # Set in evaluation mode

dataloader = DataLoader(
    ImageFolder(opt.image_folder, img_size=opt.img_size),
    batch_size=opt.batch_size,
    shuffle=False,
    num_workers=opt.n_cpu,
)

classes = load_classes(opt.class_path)  # Extracts class labels from file

Tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor

imgs = []  # Stores image paths
img_detections = []  # Stores detections for each image index

# %% [markdown]
# # Webcam Define

# %%
width = 416
height = 416

cam = cv2.VideoCapture(0)
cam.set(3, width)
cam.set(4, height)
# Out:
# True

# %% [markdown]
# # Webcam

# %%
# Bounding-box colors
cmap = plt.get_cmap("tab20b")
colors = [cmap(i) for i in np.linspace(0, 1, 20)]

frames = 0
start = time.time()

while True:
    ret_val, img = cam.read()
    # img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Mirror 
    img = cv2.flip(img, 1)
    img = cv2.resize(img, (416, 416))
    
    input_imgs = transforms.ToTensor()(img)
    input_imgs = torch.unsqueeze(input_imgs, 0).cuda()

    # Get detections
    with torch.no_grad():
        detections = model(input_imgs)
        detections = non_max_suppression(detections, opt.conf_thres, opt.nms_thres)
        img_detections.extend(detections)
    
    
#     # Create plot
#     # img = np.array(Image.open(path))
#     plt.figure()
#     fig, ax = plt.subplots(1)
#     ax.imshow(img)

#     # Draw bounding boxes and labels of detections
#     if detections is not None:
#         # Rescale boxes to original image
#         detections = rescale_boxes(detections[0], opt.img_size, img.shape[:2])

#         unique_labels = detections[:, -1].cpu().unique()
#         n_cls_preds = len(unique_labels)
#         bbox_colors = random.sample(colors, n_cls_preds)
#         for x1, y1, x2, y2, conf, cls_conf, cls_pred in detections:

# #             print("\t+ Label: %s, Conf: %.5f" % (classes[int(cls_pred)], cls_conf.item()))

#             box_w = x2 - x1
#             box_h = y2 - y1

#             color = bbox_colors[int(np.where(unique_labels == int(cls_pred))[0])]
#             # Create a Rectangle patch
#             bbox = patches.Rectangle((x1, y1), box_w, box_h, linewidth=2, edgecolor=color, facecolor="none")
#             # Add the bbox to the plot
#             ax.add_patch(bbox)
#             # Add label
#             plt.text(
#                 x1,
#                 y1,
#                 s=classes[int(cls_pred)],
#                 color="white",
#                 verticalalignment="top",
#                 bbox={"color": color, "pad": 0},
#             )

#     # Save generated image with detections
#     plt.axis("off")
#     plt.gca().xaxis.set_major_locator(NullLocator())
#     plt.gca().yaxis.set_major_locator(NullLocator())

#     fig_img = figure_to_array(fig)
    
#     plt.close()
    
    frames += 1
    print("FPS of the video is {:5.2f}".format( frames / (time.time() - start)))
    
    cv2.imshow('Demo webcam', img)
    if cv2.waitKey(1) == 27: 
        break  # esc to quit
        
cam.release()
cv2.destroyAllWindows()
# Out:
# FPS of the video is  4.18
# FPS of the video is  5.35
# FPS of the video is  7.26
# FPS of the video is  8.88
# FPS of the video is 10.30
# FPS of the video is 11.52
# FPS of the video is 12.60
# FPS of the video is 13.57
# FPS of the video is 14.48
# FPS of the video is 15.28
# FPS of the video is 16.05
# FPS of the video is 16.73
# FPS of the video is 17.37
# FPS of the video is 17.96
# FPS of the video is 18.51
# FPS of the video is 18.99
# FPS of the video is 19.42
# FPS of the video is 19.86
# FPS of the video is 20.25
# FPS of the video is 20.59
# FPS of the video is 20.95
# FPS of the video is 21.27
# FPS of the video is 21.24
# FPS of the video is 21.54
# FPS of the video is 21.83
# FPS of the video is 22.07
# FPS of the video is 22.31
# FPS of the video is 22.45
# FPS of the video is 22.65
# FPS of the video is 22.87
# FPS of the video is 23.08
# FPS of the video is 23.27
# FPS of the video is 23.49
# FPS of the video is 22.91
# FPS of the video is 23.07
# FPS of the video is 23.21
# FPS of the video is 23.37
# FPS of the video is 23.51
# FPS of the video is 23.64
# FPS of the video is 23.77
# FPS of the video is 23.91
# FPS of the video is 24.06
# FPS of the video is 24.07
# FPS of the video is 24.20
# FPS of the video is 23.90
# FPS of the video is 24.01
# FPS of the video is 24.12
# FPS of the video is 24.21
# FPS of the video is 24.33
# FPS of the video is 24.44
# FPS of the video is 24.54
# FPS of the video is 24.66
# FPS of the video is 24.60
# FPS of the video is 24.70
# FPS of the video is 24.80
# FPS of the video is 24.53
# FPS of the video is 24.62
# FPS of the video is 24.71
# FPS of the video is 24.81
# FPS of the video is 24.90
# FPS of the video is 24.98
# FPS of the video is 25.05
# FPS of the video is 25.11
# FPS of the video is 25.18
# FPS of the video is 25.23
# FPS of the video is 25.29
# FPS of the video is 25.35
# FPS of the video is 25.35
# FPS of the video is 25.42
# FPS of the video is 25.49
# FPS of the video is 25.56
# FPS of the video is 25.60
# FPS of the video is 25.65
# FPS of the video is 25.70
# FPS of the video is 25.75
# FPS of the video is 25.81
# FPS of the video is 25.86
# FPS of the video is 25.90
# FPS of the video is 25.94
# FPS of the video is 25.96
# FPS of the video is 26.00
# FPS of the video is 26.07
# FPS of the video is 26.12
# FPS of the video is 26.17
# FPS of the video is 26.23
# FPS of the video is 26.28
# FPS of the video is 26.32
# FPS of the video is 26.36
# FPS of the video is 26.41
# FPS of the video is 26.45
# FPS of the video is 26.48
# FPS of the video is 26.42
# FPS of the video is 26.46
# FPS of the video is 26.51
# FPS of the video is 26.43
# FPS of the video is 26.47
# FPS of the video is 26.51
# FPS of the video is 26.53
# FPS of the video is 26.56
# FPS of the video is 26.60
# FPS of the video is 26.63
# FPS of the video is 26.66
# FPS of the video is 26.53
# FPS of the video is 26.57
# FPS of the video is 26.61
# FPS of the video is 26.65
# FPS of the video is 26.69
# FPS of the video is 26.73
# FPS of the video is 26.76
# FPS of the video is 26.79
# FPS of the video is 26.82
# FPS of the video is 26.86
# FPS of the video is 26.89
# FPS of the video is 26.93
# FPS of the video is 26.97
# FPS of the video is 26.99
# FPS of the video is 27.02
# FPS of the video is 27.05
# FPS of the video is 27.08
# FPS of the video is 27.11
# FPS of the video is 27.14
# FPS of the video is 27.17
# FPS of the video is 27.20
# FPS of the video is 27.22
# FPS of the video is 27.22
# FPS of the video is 27.26
# FPS of the video is 27.21
# FPS of the video is 27.25
# FPS of the video is 27.27
# FPS of the video is 27.30
# FPS of the video is 27.33
# FPS of the video is 27.35
# FPS of the video is 27.37
# FPS of the video is 27.39
# FPS of the video is 27.42
# FPS of the video is 27.45
# FPS of the video is 27.38
# FPS of the video is 27.41
# FPS of the video is 27.44
# FPS of the video is 27.46
# FPS of the video is 27.49
# FPS of the video is 27.51
# FPS of the video is 27.53
# FPS of the video is 27.55
# FPS of the video is 27.57
# FPS of the video is 27.59
# FPS of the video is 27.59
# FPS of the video is 27.56
# FPS of the video is 27.58
# FPS of the video is 27.59
# FPS of the video is 27.62
# FPS of the video is 27.64
# FPS of the video is 27.67
# FPS of the video is 27.69
# FPS of the video is 27.70
# FPS of the video is 27.72
# FPS of the video is 27.74
# FPS of the video is 27.76
# FPS of the video is 27.71
# FPS of the video is 27.72
# FPS of the video is 27.74
# FPS of the video is 27.76
# FPS of the video is 27.78
# FPS of the video is 27.80
# FPS of the video is 27.81
# FPS of the video is 27.83
# FPS of the video is 27.86
# FPS of the video is 27.87
# FPS of the video is 27.82
# FPS of the video is 27.84
# FPS of the video is 27.86
# FPS of the video is 27.88
# FPS of the video is 27.89
# FPS of the video is 27.91
# FPS of the video is 27.93
# FPS of the video is 27.95
# FPS of the video is 27.96
# FPS of the video is 27.98
# FPS of the video is 27.99
# FPS of the video is 27.94
# FPS of the video is 27.96
# FPS of the video is 27.97
# FPS of the video is 27.99
# FPS of the video is 28.00
# FPS of the video is 28.02
# FPS of the video is 28.03
# FPS of the video is 28.05
# FPS of the video is 28.06
# FPS of the video is 28.08
# FPS of the video is 28.10
# FPS of the video is 28.04
# FPS of the video is 28.06
# FPS of the video is 28.07
# FPS of the video is 28.09
# FPS of the video is 28.10
# FPS of the video is 28.11
# FPS of the video is 28.12
# FPS of the video is 28.14
# FPS of the video is 28.15
# FPS of the video is 28.16
# FPS of the video is 28.12
# FPS of the video is 28.14
# FPS of the video is 28.15
# FPS of the video is 28.17
# FPS of the video is 28.18
# FPS of the video is 28.19
# FPS of the video is 28.21
# FPS of the video is 28.22
# FPS of the video is 28.23
# FPS of the video is 28.24
# FPS of the video is 28.26
# FPS of the video is 28.21
# FPS of the video is 28.22
# FPS of the video is 28.24
# FPS of the video is 28.25
# FPS of the video is 28.26
# FPS of the video is 28.28
# FPS of the video is 28.29
# FPS of the video is 28.30
# FPS of the video is 28.31
# FPS of the video is 28.33
# FPS of the video is 28.34
# FPS of the video is 28.29
# FPS of the video is 28.30
# FPS of the video is 28.32
# FPS of the video is 28.33
# FPS of the video is 28.34
# FPS of the video is 28.35
# FPS of the video is 28.36
# FPS of the video is 28.37
# FPS of the video is 28.39
# FPS of the video is 28.40
# FPS of the video is 28.41
# FPS of the video is 28.36
# FPS of the video is 28.37
# FPS of the video is 28.38
# FPS of the video is 28.39
# FPS of the video is 28.40
# FPS of the video is 28.42
# FPS of the video is 28.42
# FPS of the video is 28.43
# FPS of the video is 28.45
# FPS of the video is 28.46
# FPS of the video is 28.42
# FPS of the video is 28.33
